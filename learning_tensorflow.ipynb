# %% [markdown]
# <a href="https://colab.research.google.com/github/shohan12727/TensorFlow/blob/main/learning_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Initialization**

# %%
import tensorflow as tf

# %% [markdown]
# ### **Main code**

# %%
tensor = tf.constant([1,2,3,20,5,8])
tensor.shape
# Out:
# TensorShape([6])

# %%
squeezed = tf.squeeze(tensor)
squeezed
squeezed.shape
# Out:
# TensorShape([6])

# %% [markdown]
# # *Another example*

# %%
t2 = tf.constant([[34,54,65,23,5]])
tf.squeeze(t2)
# Out:
# <tf.Tensor: shape=(5,), dtype=int32, numpy=array([34, 54, 65, 23,  5], dtype=int32)>

# %%
t3 = tf.constant([
    [1,2,3,4],
    [5,6,7,9],
    [5,7,8,90]
])
tf.squeeze(t3)
# Out:
# <tf.Tensor: shape=(3, 4), dtype=int32, numpy=
# array([[ 1,  2,  3,  4],
#        [ 5,  6,  7,  9],
#        [ 5,  7,  8, 90]], dtype=int32)>

# %% [markdown]
# ### tf.squeeze() only removes dimensions whose size is exactly 1
