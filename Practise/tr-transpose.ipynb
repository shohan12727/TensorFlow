# %% [markdown]
# <a href="https://colab.research.google.com/github/shohan12727/TensorFlow/blob/main/tr-transpose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Initialization**

# %%
import tensorflow as tf

# %% [markdown]
# ### **Main code**

# %%
t1 = tf.constant([
    [1,2,3,4],
    [2,3,4,5]
])
tf.transpose(t1)
# Out:
# <tf.Tensor: shape=(4, 2), dtype=int32, numpy=
# array([[1, 2],
#        [2, 3],
#        [3, 4],
#        [4, 5]], dtype=int32)>
